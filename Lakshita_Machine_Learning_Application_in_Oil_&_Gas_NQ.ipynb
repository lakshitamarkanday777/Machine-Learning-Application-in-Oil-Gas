# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Machine learning techniques can be applied to various aspects of the oil and gas industry to improve efficiency, optimize operations, and make better data-driven decisions. Here are some common applications of machine learning in the oil and gas sector:
#
# **Predictive Maintenance:** Machine learning algorithms can analyze sensor data from equipment and machinery to identify patterns and predict potential failures or maintenance needs. By monitoring key parameters, such as temperature, pressure, and vibration, predictive maintenance models can help prevent costly breakdowns and optimize maintenance schedules.
#
# **Production Optimization:** Machine learning can be used to optimize production processes by analyzing vast amounts of data from various sources, including well sensors, drilling logs, and historical production records. By identifying patterns and correlations, machine learning models can provide insights to improve production efficiency, reduce downtime, and optimize reservoir management.
#
# **Reservoir Characterization:** Machine learning algorithms can analyze seismic data, well logs, and production data to create accurate reservoir models. These models help geoscientists and engineers understand the subsurface characteristics, such as rock porosity, permeability, and fluid saturation, enabling better decision-making for exploration and production activities.
#
# **Drilling Optimization:** Machine learning can be used to optimize drilling operations by analyzing historical drilling data and real-time sensor data from the drilling rig. By identifying patterns and anomalies, machine learning models can provide insights to optimize drilling parameters, reduce drilling time, and enhance safety.
#
# **Asset Integrity and Safety:** Machine learning techniques can analyze sensor data from equipment, pipelines, and infrastructure to detect anomalies and potential safety risks. By monitoring factors like temperature, pressure, corrosion levels, and leak detection, machine learning models can help identify and prevent equipment failures, leaks, or hazardous conditions.
#
# **Energy Demand Forecasting:** Machine learning models can analyze historical energy consumption data, weather patterns, and other relevant factors to forecast future energy demand. This helps oil and gas companies optimize production and distribution plans, manage inventory, and improve energy trading strategies.
#
# **Natural Language Processing (NLP)**: NLP techniques can be applied to analyze unstructured data sources, such as documents, reports, and research papers, to extract valuable insights. For example, NLP can be used to automate the extraction of relevant information from drilling reports or to monitor news and social media for sentiment analysis and market trends.
#
# These are just a few examples of how machine learning can be applied in the oil and gas industry. The specific applications and benefits depend on the available data, industry domain, and the objectives of the company.

# %% [markdown]
# # Reservoir Characterization
#
# For this exercise we are going to focus on the application of Machine Learning Models to  Reservoir Characterization.
#
# Machine learning techniques can greatly assist in reservoir characterization, which involves understanding the subsurface properties and behavior of oil and gas reservoirs. Here are some detailed explanations and examples of how machine learning can be applied in reservoir characterization:
#
# **Seismic Data Interpretation: **Seismic data provides valuable information about the subsurface structures and properties. Machine learning algorithms can be applied to seismic data for tasks such as seismic interpretation, attribute analysis, and seismic facies classification. By training on labeled examples, machine learning models can learn to recognize patterns and interpret seismic attributes, aiding in identifying potential hydrocarbon reservoirs.
# Example: Convolutional Neural Networks (CNNs) can be employed to automatically extract features from seismic data. By training on labeled seismic sections where reservoirs are known to be present, the CNN can learn to identify similar patterns in unlabeled seismic data, helping in reservoir identification.
#
# **Well Log Analysis:** Well logs contain measurements of various properties, such as gamma-ray, resistivity, porosity, and permeability, which provide insights into the subsurface characteristics. Machine learning algorithms can analyze well log data to predict missing log curves, estimate rock properties, and identify lithology.
# Example: Support Vector Machines (SVMs) can be utilized to classify rock types based on well log data. By training on a set of well logs with known rock types, the SVM can learn to classify new wells based on their log responses, aiding in lithology prediction and reservoir characterization.
#
# **Petrophysical Analysis:** Petrophysical analysis involves estimating reservoir properties, such as fluid saturation, porosity, and permeability, using well log measurements. Machine learning techniques can be applied to well log data to build models that predict these properties more accurately.
# Example: Random Forest regression models can be trained on a dataset containing well logs and corresponding core data. The model can then predict reservoir properties, such as porosity and permeability, using new well log data as input. This enables a faster and more accurate estimation of reservoir properties.
#
# **Fluid Identification:** Identifying different fluids within the reservoir, such as oil, gas, and water, is crucial for reservoir characterization. Machine learning algorithms can be employed to analyze well log data, seismic attributes, and production data to determine fluid types and distributions.
# Example: Unsupervised learning algorithms, such as clustering techniques like K-means or Gaussian Mixture Models, can be applied to well log data to group similar log responses together. This can help in identifying distinct fluid types within the reservoir and understanding their spatial distribution.
#
# **Geological Facies Analysis:** Geological facies analysis involves identifying and characterizing different sedimentary facies within a reservoir. Machine learning algorithms can analyze various data sources, including well logs, core data, and seismic attributes, to classify and model different facies.
# Example: Recurrent Neural Networks (RNNs) can be used to analyze well log data sequences and predict facies classes. By training on a dataset of well logs with corresponding facies labels, the RNN can learn the temporal patterns in the logs and classify facies in new wells.
#
# These examples demonstrate how machine learning can be applied to reservoir characterization. By leveraging large volumes of data and learning patterns from labeled examples, machine learning models can enhance the understanding of reservoir properties, improve predictions, and optimize exploration and production strategies.

# %% [markdown]
# # Exploring the Dataset

# %% [markdown]
# The data set we will use comes from a University of Kansas class exercise on the Hugoton and Panoma gas fields.
#
#
# The data set consists of seven features
#
# (five wireline log measurements
#
#  two indicator variables- last 2
#
#  a facies label at half-foot depth intervals.(Shale ( Sandstone , Limestone etc)
#
#  In machine learning terminology, the set of measurements at each depth interval comprises a feature vector, each of which is associated with a class (the facies type).
#
# Gamma ray (GR)
#
# Resistivity (ILD_log10)
#
# Photoelectric effect (PE)
#
# Neutron-density porosity difference (DeltaPHI)
#
# Average neutron-density porosity (PHIND)
#
# Nonmarine/marine indicator (NM_M)
#
# Relative position (RELPOS)

# %%
import pandas as pd

# %%
data = pd.read_csv('training_data.csv')

# %%
data.head()
# Out:
#    Facies Formation  Well Name   Depth     GR  ILD_log10  DeltaPHI   PHIND  \
# 0       3     A1 SH  SHRIMPLIN  2793.0  77.45      0.664       9.9  11.915
# 1       3     A1 SH  SHRIMPLIN  2793.5  78.26      0.661      14.2  12.565
# 2       3     A1 SH  SHRIMPLIN  2794.0  79.05      0.658      14.8  13.050
# 3       3     A1 SH  SHRIMPLIN  2794.5  86.10      0.655      13.9  13.115
# 4       3     A1 SH  SHRIMPLIN  2795.0  74.58      0.647      13.5  13.300
#
#     PE  NM_M  RELPOS
# 0  4.6     1   1.000
# 1  4.1     1   0.979
# 2  3.6     1   0.957
# 3  3.5     1   0.936
# 4  3.4     1   0.915

# %% [markdown]
# Note the Well names

# %%
data.tail()
# Out:
#       Facies Formation        Well Name   Depth      GR  ILD_log10  DeltaPHI  \
# 3227       5      C LM  CHURCHMAN BIBLE  3120.5  46.719      0.947     1.828
# 3228       5      C LM  CHURCHMAN BIBLE  3121.0  44.563      0.953     2.241
# 3229       5      C LM  CHURCHMAN BIBLE  3121.5  49.719      0.964     2.925
# 3230       5      C LM  CHURCHMAN BIBLE  3122.0  51.469      0.965     3.083
# 3231       5      C LM  CHURCHMAN BIBLE  3122.5  50.031      0.970     2.609
#
#       PHIND     PE  NM_M  RELPOS
# 3227  7.254  3.617     2   0.685
# 3228  8.013  3.344     2   0.677
# 3229  8.013  3.190     2   0.669
# 3230  7.708  3.152     2   0.661
# 3231  6.668  3.295     2   0.653

# %% [markdown]
# There are nine facies classes (numbered 1–9) identified in the data set. The table below contains the descriptions associated with these classes. Note that not all of these facies are completely discrete; some gradually blend in to one another. Misclassification of these neighboring facies can be expected to occur.
#
#
# ![image.png](data:image/png;base64,...)

# %%
data.describe()
# Out:
#             Facies        Depth           GR    ILD_log10     DeltaPHI  \
# count  3232.000000  3232.000000  3232.000000  3232.000000  3232.000000
# mean      4.422030  2875.824567    66.135769     0.642719     3.559642
# std       2.504243   131.006274    30.854826     0.241845     5.228948
# min       1.000000  2573.500000    13.250000    -0.025949   -21.832000
# 25%       2.000000  2791.000000    46.918750     0.492750     1.163750
# 50%       4.000000  2893.500000    65.721500     0.624437     3.500000
# 75%       6.000000  2980.000000    79.626250     0.812735     6.432500
# max       9.000000  3122.500000   361.150000     1.480000    18.600000
#
#              PHIND           PE         NM_M       RELPOS
# count  3232.000000  3232.000000  3232.000000  3232.000000
# mean     13.483213     3.725014     1.498453     0.520287
# std       7.698980     0.896152     0.500075     0.286792
# min       0.550000     0.200000     1.000000     0.010000
# ...

# %% [markdown]
# To evaluate the accuracy of the classifier, we will remove one well from the training set so that we can compare the predicted and actual facies labels.

# %%
data['Well Name'].unique()
# Out:
# array(['SHRIMPLIN', 'SHANKLE', 'LUKE G U', 'CROSS H CATTLE', 'NOLAN',
#        'Recruit F9', 'NEWBY', 'CHURCHMAN BIBLE'], dtype=object)

# %%
test_well = data[data['Well Name'] == 'SHANKLE']

# %%
test_well.head()
# Out:
#      Facies Formation Well Name   Depth     GR  ILD_log10  DeltaPHI   PHIND  \
# 471       2     A1 SH   SHANKLE  2774.5  98.36      0.642      -0.1  18.685
# 472       2     A1 SH   SHANKLE  2775.0  97.57      0.631       7.9  16.745
# 473       2     A1 SH   SHANKLE  2775.5  98.41      0.615      12.8  14.105
# 474       2     A1 SH   SHANKLE  2776.0  85.92      0.597      13.0  13.385
# 475       2     A1 SH   SHANKLE  2776.5  83.16      0.592      12.3  13.345
#
#       PE  NM_M  RELPOS
# 471  2.9     1   1.000
# 472  3.2     1   0.984
# 473  3.2     1   0.968
# 474  3.4     1   0.952
# 475  3.4     1   0.935

# %%
#drop SHANKLE from dataframe
data = data[data['Well Name'] != 'SHANKLE']

# %%
data.head()
# Out:
#    Facies Formation  Well Name   Depth     GR  ILD_log10  DeltaPHI   PHIND  \
# 0       3     A1 SH  SHRIMPLIN  2793.0  77.45      0.664       9.9  11.915
# 1       3     A1 SH  SHRIMPLIN  2793.5  78.26      0.661      14.2  12.565
# 2       3     A1 SH  SHRIMPLIN  2794.0  79.05      0.658      14.8  13.050
# 3       3     A1 SH  SHRIMPLIN  2794.5  86.10      0.655      13.9  13.115
# 4       3     A1 SH  SHRIMPLIN  2795.0  74.58      0.647      13.5  13.300
#
#     PE  NM_M  RELPOS
# 0  4.6     1   1.000
# 1  4.1     1   0.979
# 2  3.6     1   0.957
# 3  3.5     1   0.936
# 4  3.4     1   0.915

# %% [markdown]
# Let's extract the feature vectors anfacies_labelsfafaff___iated facies labels from the training data set:

# %%
features= data.drop(['Facies'], axis =1)
features.head()
# Out:
#   Formation  Well Name   Depth     GR  ILD_log10  DeltaPHI   PHIND   PE  NM_M  \
# 0     A1 SH  SHRIMPLIN  2793.0  77.45      0.664       9.9  11.915  4.6     1
# 1     A1 SH  SHRIMPLIN  2793.5  78.26      0.661      14.2  12.565  4.1     1
# 2     A1 SH  SHRIMPLIN  2794.0  79.05      0.658      14.8  13.050  3.6     1
# 3     A1 SH  SHRIMPLIN  2794.5  86.10      0.655      13.9  13.115  3.5     1
# 4     A1 SH  SHRIMPLIN  2795.0  74.58      0.647      13.5  13.300  3.4     1
#
#    RELPOS
# 0   1.000
# 1   0.979
# 2   0.957
# 3   0.936
# 4   0.915

# %%
#Drop unneccessary columns. Formation is similar to facies. Well name & depth not relevant in predicting Facies type.
features= features.drop(['Formation', 'Well Name', 'Depth'], axis =1)
features.head()
# Out:
#       GR  ILD_log10  DeltaPHI   PHIND   PE  NM_M  RELPOS
# 0  77.45      0.664       9.9  11.915  4.6     1   1.000
# 1  78.26      0.661      14.2  12.565  4.1     1   0.979
# 2  79.05      0.658      14.8  13.050  3.6     1   0.957
# 3  86.10      0.655      13.9  13.115  3.5     1   0.936
# 4  74.58      0.647      13.5  13.300  3.4     1   0.915

# %%
facies_labels = data['Facies'].values

# %%
facies_labels
# Out:
# array([3, 3, 3, ..., 5, 5, 5])

# %% [markdown]
# # Visualize the rock type

# %%
import seaborn as sns
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %% [markdown]
# Before we plot the well data, let's define a color map so the facies are represented by consistent color in all the plots in this tutorial. We also create the abbreviated facies labels, and add those to the facies_vectors dataframe.

# %%
# 1=sandstone  2=c_siltstone   3=f_siltstone
# 4=marine_silt_shale 5=mudstone 6=wackestone 7=dolomite
# 8=packstone 9=bafflestone
facies_colors = ['#F4D03F', '#F5B041','#DC7633','#6E2C00',
       '#1B4F72','#2E86C1', '#AED6F1', '#A569BD', '#196F3D']

facies_labels = ['SS', 'CSiS', 'FSiS', 'SiSh', 'MS',
                 'WS', 'D','PS', 'BS']
#facies_color_map is a dictionary that maps facies labels
#to their respective colors
facies_color_map = {}
for ind, label in enumerate(facies_labels):
    facies_color_map[label] = facies_colors[ind]

def label_facies(row, labels):
    return labels[ row['Facies'] -1]

data.loc[:,'FaciesLabels'] = data.apply(lambda row: label_facies(row, facies_labels), axis=1)

# %%
sns.set()
sns.pairplot(data.drop(['Well Name','Facies','Formation','Depth','NM_M','RELPOS'],axis=1),
             hue='FaciesLabels', palette=facies_color_map,
             hue_order=list(reversed(facies_labels)))

# %% [markdown]
# Let's take a look at the data from individual wells in a more familiar log plot form. We will create plots for the five well log variables, as well as a log for facies labels.

# %%
def make_facies_log_plot(logs, facies_colors):
    #make sure logs are sorted by depth
    logs = logs.sort_values(by='Depth')
    cmap_facies = colors.ListedColormap(
            facies_colors[0:len(facies_colors)], 'indexed')

    ztop=logs.Depth.min(); zbot=logs.Depth.max()

    cluster=np.repeat(np.expand_dims(logs['Facies'].values,1), 100, 1)

    f, ax = plt.subplots(nrows=1, ncols=6, figsize=(8, 12))
    ax[0].plot(logs.GR, logs.Depth, '-g')
    ax[1].plot(logs.ILD_log10, logs.Depth, '-')
    ax[2].plot(logs.DeltaPHI, logs.Depth, '-', color='0.5')
    ax[3].plot(logs.PHIND, logs.Depth, '-', color='r')
    ax[4].plot(logs.PE, logs.Depth, '-', color='black')
    im=ax[5].imshow(cluster, interpolation='none', aspect='auto',
                    cmap=cmap_facies,vmin=1,vmax=9)

    divider = make_axes_locatable(ax[5])
    cax = divider.append_axes("right", size="20%", pad=0.05)
    cbar=plt.colorbar(im, cax=cax)
    cbar.set_label((17*' ').join([' SS ', 'CSiS', 'FSiS',
                                'SiSh', ' MS ', ' WS ', ' D  ',
                                ' PS ', ' BS ']))
    cbar.set_ticks(range(0,1)); cbar.set_ticklabels('')

    for i in range(len(ax)-1):
        ax[i].set_ylim(ztop,zbot)
        ax[i].invert_yaxis()
        ax[i].grid()
        ax[i].locator_params(axis='x', nbins=3)

    ax[0].set_xlabel("GR")
    ax[0].set_xlim(logs.GR.min(),logs.GR.max())
    ax[1].set_xlabel("ILD_log10")
    ax[1].set_xlim(logs.ILD_log10.min(),logs.ILD_log10.max())
    ax[2].set_xlabel("DeltaPHI")
    ax[2].set_xlim(logs.DeltaPHI.min(),logs.DeltaPHI.max())
    ax[3].set_xlabel("PHIND")
    ax[3].set_xlim(logs.PHIND.min(),logs.PHIND.max())
    ax[4].set_xlabel("PE")
    ax[4].set_xlim(logs.PE.min(),logs.PE.max())
    ax[5].set_xlabel('Facies')

    ax[1].set_yticklabels([]); ax[2].set_yticklabels([]); ax[3].set_yticklabels([])
    ax[4].set_yticklabels([]); ax[5].set_yticklabels([])
    ax[5].set_xticklabels([])
    f.suptitle('Well: %s'%logs.iloc[0]['Well Name'], fontsize=14,y=0.94)

# %%
make_facies_log_plot(
    data[data['Well Name'] == 'SHRIMPLIN'],
    facies_colors)

# %% [markdown]
# In addition to individual wells, we can look at how the various facies are represented by the entire training set.  Let's plot a histgram of the number of training examples for each facies class.

# %%
#count the number of unique entries for each facies, sort them by
#facies number (instead of by number of entries)
facies_counts = data['Facies'].value_counts().sort_index()
#use facies labels to index each count
facies_counts.index = facies_labels

facies_counts.plot(kind='bar',color=facies_colors,
                   title='Distribution of Training Data by Facies')
facies_counts
# Out:
# SS      170
# CSiS    649
# FSiS    498
# SiSh    177
# MS      198
# WS      391
# D        81
# PS      458
# BS      161
# Name: count, dtype: int64

# %% [markdown]
# # Machine Learning

# %%
data.head()
# Out:
#    Facies Formation  Well Name   Depth     GR  ILD_log10  DeltaPHI   PHIND  \
# 0       3     A1 SH  SHRIMPLIN  2793.0  77.45      0.664       9.9  11.915
# 1       3     A1 SH  SHRIMPLIN  2793.5  78.26      0.661      14.2  12.565
# 2       3     A1 SH  SHRIMPLIN  2794.0  79.05      0.658      14.8  13.050
# 3       3     A1 SH  SHRIMPLIN  2794.5  86.10      0.655      13.9  13.115
# 4       3     A1 SH  SHRIMPLIN  2795.0  74.58      0.647      13.5  13.300
#
#     PE  NM_M  RELPOS FaciesLabels
# 0  4.6     1   1.000         FSiS
# 1  4.1     1   0.979         FSiS
# 2  3.6     1   0.957         FSiS
# 3  3.5     1   0.936         FSiS
# 4  3.4     1   0.915         FSiS

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
# Drop any rows with missing values
data = data.dropna()

# %%
# Encode categorical variables
le = LabelEncoder()
data['Formation'] = le.fit_transform(data['Formation'])
data['Well Name'] = le.fit_transform(data['Well Name'])
data['FaciesLabels'] = le.fit_transform(data['Facies'])

# %%
# Drop the original 'Facies' column if needed
data = data.drop('Facies', axis=1)

# %%
# Split data into features (X) and labels (y)
X = data.drop('FaciesLabels', axis=1)
y = data['FaciesLabels']

# %%
# Standardize numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
# Now, X_train and X_test contain the features, and y_train and y_test contain the labels.

# %% [markdown]
# ## Training the SVM classifier
#
# Now we use the cleaned and conditioned training set to create a facies classifier.  As mentioned above, we will use a type of machine learning model known as a [support vector machine](https://en.wikipedia.org/wiki/Support_vector_machine).  The SVM is a map of the feature vectors as points in a multi dimensional space, mapped so that examples from different facies are divided by a clear gap that is as wide as possible.
#
# The SVM implementation in [scikit-learn](http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html#sklearn.svm.SVC) takes a number of important parameters.  First we create a classifier using the default settings.

# %%
from sklearn import svm

SVM = svm.SVC()

# %% [markdown]
# Now we can train the classifier using the training set we created above.

# %%
SVM.fit(X_train,y_train)
# Out:
# SVC()

# %% [markdown]
# Now that the model has been trained on our data, we can use it to predict the facies of the feature vectors in the test set.  Because we know the true facies labels of the vectors in the test set, we can use the results to evaluate the accuracy of the classifier.

# %%
predicted_labels = SVM.predict(X_test)

# %% [markdown]
# We need some metrics to evaluate how good our classifier is doing.  A [confusion matrix](http://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/) is a table that can be used to describe the performance of a classification model.  [Scikit-learn](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) allows us to easily create a confusion matrix by supplying the actual and predicted facies labels.
#
# The confusion matrix is simply a 2D array.  The entries of confusion matrix `C[i][j]` are equal to the number of observations predicted to have facies `j`, but are known to have facies `i`.
#
# To simplify reading the confusion matrix, a function has been written to display the matrix along with facies labels and various error metrics.  See the file `classification_utilities.py` in this repo for the `display_cm()` function.

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
print("SVM Accuracy:", accuracy_score(y_test, predicted_labels))
# Out:
# SVM Accuracy: 0.6983842010771992

# %%
print(classification_report(y_test, predicted_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.77      0.83        39
#            1       0.77      0.82      0.79       130
#            2       0.69      0.73      0.71        84
#            3       0.64      0.76      0.69        33
#            4       0.86      0.32      0.46        60
#            5       0.49      0.62      0.55        72
#            6       0.85      0.65      0.73        17
#            7       0.65      0.73      0.69        88
#            8       0.80      0.82      0.81        34
#
#     accuracy                           0.70       557
#    macro avg       0.74      0.69      0.70       557
# weighted avg       0.72      0.70      0.69       557

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# Implement K-Nearest Neighbors (KNN)
knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# Implement Decision Trees
decision_tree = DecisionTreeClassifier(max_depth=5)  # You can adjust the maximum depth
decision_tree.fit(X_train, y_train)
y_pred_decision_tree = decision_tree.predict(X_test)

# Implement Random Forest
random_forest = RandomForestClassifier(n_estimators=100)  # You can adjust the number of trees (n_estimators)
random_forest.fit(X_train, y_train)
y_pred_random_forest = random_forest.predict(X_test)

# %%
# Evaluate the models
print("K-Nearest Neighbors (KNN) Accuracy:", accuracy_score(y_test, y_pred_knn))
print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_decision_tree))
print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_random_forest))
# Out:
# K-Nearest Neighbors (KNN) Accuracy: 0.7612208258527827
# Decision Tree Accuracy: 0.5565529622980251
# Random Forest Accuracy: 0.7935368043087971

# %% [markdown]
# Random Forest seems to be doing better than the rest.

# %%
print("\nClassification Report for Random Forest:")
print(classification_report(y_test, y_pred_random_forest))
# Out:
# Classification Report for Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90        39
#            1       0.85      0.94      0.89       130
#            2       0.84      0.80      0.82        84
#            3       0.75      0.82      0.78        33
#            4       0.79      0.63      0.70        60
#            5       0.66      0.62      0.64        72
#            6       0.86      0.71      0.77        17
#            7       0.67      0.75      0.71        88
#            8       0.91      0.94      0.93        34
#
#     accuracy                           0.79       557
#    macro avg       0.81      0.78      0.79       557
# weighted avg       0.80      0.79      0.79       557

# %% [markdown]
# ## Applying the classification model to the blind data
#
# We held a well back (SHANKLE) from the training, and stored it in a dataframe called `test_well`:

# %%
test_well.head()
# Out:
#      Facies Formation Well Name   Depth     GR  ILD_log10  DeltaPHI   PHIND  \
# 471       2     A1 SH   SHANKLE  2774.5  98.36      0.642      -0.1  18.685
# 472       2     A1 SH   SHANKLE  2775.0  97.57      0.631       7.9  16.745
# 473       2     A1 SH   SHANKLE  2775.5  98.41      0.615      12.8  14.105
# 474       2     A1 SH   SHANKLE  2776.0  85.92      0.597      13.0  13.385
# 475       2     A1 SH   SHANKLE  2776.5  83.16      0.592      12.3  13.345
#
#       PE  NM_M  RELPOS
# 471  2.9     1   1.000
# 472  3.2     1   0.984
# 473  3.2     1   0.968
# 474  3.4     1   0.952
# 475  3.4     1   0.935

# %%
# Drop any rows with missing values
test_well = test_well.dropna()

# %%
# Encode categorical variables using the same LabelEncoder used for training data
test_well['Formation'] = le.fit_transform(test_well['Formation'])
test_well['Well Name'] = le.fit_transform(test_well['Well Name'])

# %%
test_well.head()
# Out:
#      Facies  Formation  Well Name   Depth     GR  ILD_log10  DeltaPHI   PHIND  \
# 471       2          1          0  2774.5  98.36      0.642      -0.1  18.685
# 472       2          1          0  2775.0  97.57      0.631       7.9  16.745
# 473       2          1          0  2775.5  98.41      0.615      12.8  14.105
# 474       2          1          0  2776.0  85.92      0.597      13.0  13.385
# 475       2          1          0  2776.5  83.16      0.592      12.3  13.345
#
#       PE  NM_M  RELPOS
# 471  2.9     1   1.000
# 472  3.2     1   0.984
# 473  3.2     1   0.968
# 474  3.4     1   0.952
# 475  3.4     1   0.935

# %%
# Standardize numerical features using the same StandardScaler used for training data
X_test_well_scaled = scaler.transform(test_well.drop(['Facies'], axis=1))

# %%
# Make predictions on the test data
predictions = random_forest.predict(X_test_well_scaled)

# %%
# Print the classification report
print("Classification Report:")
print(classification_report(test_well['Facies'], predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.34      0.64      0.44        89
#            2       0.31      0.30      0.31        89
#            3       0.00      0.00      0.00       117
#            4       0.00      0.00      0.00         7
#            5       0.02      0.05      0.02        19
#            6       0.00      0.00      0.00        71
#            7       0.12      0.53      0.20        17
#            8       0.00      0.00      0.00        40
#
#     accuracy                           0.21       449
#    macro avg       0.09      0.17      0.11       449
# weighted avg       0.13      0.21      0.16       449
# ...

# %% [markdown]
# # Interview Readiness Questions

# %% [markdown]
# At 20% this is not so great. What else could you do to optimize this model
# Some suggestions:
# 1. Rerun the model without standardization
# 2. Try Different Machine Learning Algorithms including Cross Validation
# 3. Troubleshoot the code. Did you identify any errors?
# 4. Show your results & insights
# 5. What are some potential limitations and challenges of applying machine learning in the oil and gas industry, and how can they be overcome?

# %% [markdown]
# # Rerun the Model without Standardization
# Standardization enhances the performance of numerous machine learning models because it makes all features contribute equal value to the model framework. Random Forest models that use decision tree algorithms do not get affected by feature scaling since they operate independently of distance-based algorithms. The elimination of standardization appears to offer potential benefits or equivalent outcomes for the model performance. The performance results of the model should be measured after conducting a new run by eliminating feature standardization.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder, StandardScaler
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv('training_data.csv')

# Encode categorical features
df_encoded = data.copy()
le_formation = LabelEncoder()
le_wellname = LabelEncoder()

df_encoded['Formation'] = le_formation.fit_transform(df_encoded['Formation'])
df_encoded['Well Name'] = le_wellname.fit_transform(df_encoded['Well Name'])

# Define feature variables and target labels
X = df_encoded.drop(columns=['Facies'])
y = df_encoded['Facies']

# Check for class imbalance
print("Class distribution (count):")
print(y.value_counts())

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, y)

# Check class distribution after SMOTE
print("Class distribution after SMOTE:")
print(pd.Series(y_resampled).value_counts())

# Split data into training and validation sets (using resampled data)
X_train, X_val, y_train, y_val = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)
# Out:
# Class distribution (count):
# Facies
# 2    738
# 3    615
# 8    498
# 6    462
# 1    259
# 5    217
# 4    184
# 9    161
# 7     98
# Name: count, dtype: int64
# Class distribution after SMOTE:
# Facies
# 3    738
# 2    738
# 8    738
# 6    738
# 7    738
# 4    738
# 5    738
# 9    738
# 1    738
# Name: count, dtype: int64

# %%
# Training RandomForest
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Evaluate model performance on validation set
y_pred = clf.predict(X_val)
print("\nClassification Report (Random Forest):")
print(classification_report(y_val, y_pred))

# Train Gradient Boosting (as an alternative)
gb_clf = GradientBoostingClassifier(random_state=42)
gb_clf.fit(X_train, y_train)

# Evaluate Gradient Boosting model performance on validation set
y_pred_gb = gb_clf.predict(X_val)
print("\nClassification Report (Gradient Boosting):")
print(classification_report(y_val, y_pred_gb))
# Out:
# Classification Report (Random Forest):
#               precision    recall  f1-score   support
#
#            1       0.97      0.97      0.97       139
#            2       0.89      0.89      0.89       148
#            3       0.92      0.90      0.91       148
#            4       0.91      0.93      0.92       151
#            5       0.95      0.92      0.94       152
#            6       0.88      0.87      0.88       156
#            7       0.97      0.98      0.98       147
#            8       0.87      0.89      0.88       142
#            9       0.99      0.99      0.99       146
#
#     accuracy                           0.93      1329
#    macro avg       0.93      0.93      0.93      1329
# weighted avg       0.93      0.93      0.93      1329
#
#
# Classification Report (Gradient Boosting):
#               precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95       139
#            2       0.78      0.78      0.78       148
# ...

# %%
# Based on performance was by Random Forest so using it for the test well prediction.

# Now, for the Test Well predictions:
# Preprocess test well data in the same way as training data to align the structure
test_well_encoded = test_well.copy()   # just cpying the set to new var cuz we already encoded in the org set , no need of encoding again

# Separate features from the target variable
X_test = test_well_encoded.drop(columns=['Facies'])
X_test_scaled = scaler.transform(X_test)
# Make predictions on the test well data using the trained model
predictions = clf.predict(X_test_scaled)

# Print the classification report for the test well data
print("\nClassification Report for Test Well Data (Random Forest):")
print(classification_report(test_well['Facies'], predictions))
# Out:
# Classification Report for Test Well Data (Random Forest):
#               precision    recall  f1-score   support
#
#            1       0.91      1.00      0.95        89
#            2       0.91      0.87      0.89        89
#            3       0.97      0.93      0.95       117
#            4       0.88      1.00      0.93         7
#            5       1.00      0.95      0.97        19
#            6       0.99      0.96      0.97        71
#            7       1.00      1.00      1.00        17
#            8       0.93      0.97      0.95        40
#
#     accuracy                           0.94       449
#    macro avg       0.95      0.96      0.95       449
# weighted avg       0.95      0.94      0.94       449

# %% [markdown]
# **4. Show your results & insights**

# %%
# Evaluate model performance on validation set
y_pred = clf.predict(X_val)
print("\nClassification Report (Random Forest) best model:")
print(classification_report(y_val, y_pred))


# Print the classification report for the test well data
print("\nClassification Report for Test Well Data (Random Forest):")
print(classification_report(test_well['Facies'], predictions))


from sklearn.metrics import confusion_matrix
import seaborn as sns

conf_matrix = confusion_matrix(test_well['Facies'], predictions)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=le_formation.classes_, yticklabels=le_formation.classes_)
plt.title("Confusion Matrix for Test Well Data")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Classification Report (Random Forest) best model:
#               precision    recall  f1-score   support
#
#            1       0.97      0.97      0.97       139
#            2       0.89      0.89      0.89       148
#            3       0.92      0.90      0.91       148
#            4       0.91      0.93      0.92       151
#            5       0.95      0.92      0.94       152
#            6       0.88      0.87      0.88       156
#            7       0.97      0.98      0.98       147
#            8       0.87      0.89      0.88       142
#            9       0.99      0.99      0.99       146
#
#     accuracy                           0.93      1329
#    macro avg       0.93      0.93      0.93      1329
# weighted avg       0.93      0.93      0.93      1329
#
#
# Classification Report for Test Well Data (Random Forest):
#               precision    recall  f1-score   support
#
#            1       0.91      1.00      0.95        89
# ...

# %% [markdown]
# **5.What are some potential limitations and challenges of applying machine learning in the oil and gas industry, and how can they be overcome?**
#
# The use of machine learning techniques in the oil and gas sector presents three main difficulties including:
#
# * **Data Quality and Availability:**
#   The precision of models suffers substantial degradation when data contains unfinished datasets or significant flaws or inconsistent measurements.
#
#   The solution involves adopting thorough preprocessing methods to treat the dataset before model production. The validation of all data depends on utilizing expert knowledge from the specific domain.
#
# * **Class Imbalance:**
#   The learning accuracy of machine learning models tends to deteriorate from class imbalance when rare events like drilling faults need priority attention.
#
#   The utilization of SMOTE (your selected technique) and undersampling or cost-sensitive learning presents solutions.
#
# * **Interpretability of Models:**
#
#   Random Forests and Gradient Boosting along with various other machine learning models operate as black box systems that lead to unpredictable prediction explanations.
#
#   Organizations should employ SHAP values and LIME to achieve decision interpretation which helps stakeholders develop trust in model-based results.
#
# * **Feature Selection:**
#
#   Many of the numerous characteristics found in oil and gas data fail to provide significant model value.
#
#   The process of selecting and engineering features provides a solution to enhance both model efficiency and interpretability.
#
# * **Scalability and Real-Time Decision Making:**
#
#   Real-time predictions involving equipment failure forecasts require quick models to function properly but such performance proves difficult to achieve from complex mathematical algorithms.
#
#   Model optimization techniques and simpler models should be implemented to increase prediction speed.
#
# **How to Overcome These Challenges:**
#
# * The organization should acquire data collection tools that deliver precise high-quality data results.
#
# * Domestic experts need to directly assist with model development through active partnership for determining which features will be meaningful.
#
# * You should test different models along with parameter adjustments to earn better performance results.
#
# * SHAP together with LIME serves as tools for improving model interpretability since interpretability matters especially in critical industries such as oil and gas.

# %% [markdown]
# # Checking the class imbalance

# %% [markdown]
# ## References
#
# Dubois et al. (2007) http://github.com/seg.[1]
#
# Amato del Monte, A., 2015. Seismic Petrophysics: Part 1, *The Leading Edge*, 34 (4). [doi:10.1190/tle34040440.1](http://dx.doi.org/10.1190/tle34040440.1)
#
# Bohling, G. C., and M. K. Dubois, 2003. An Integrated Application of Neural Network and Markov Chain Techniques to Prediction of Lithofacies from Well Logs, *KGS Open-File Report* 2003-50, 6 pp. [pdf](http://www.kgs.ku.edu/PRS/publication/2003/ofr2003-50.pdf)
#
# Dubois, M. K., G. C. Bohling, and S. Chakrabarti, 2007, Comparison of four approaches to a rock facies classification problem, *Computers & Geosciences*, 33 (5), 599-617 pp. [doi:10.1016/j.cageo.2006.08.011](http://dx.doi.org/10.1016/j.cageo.2006.08.011)
